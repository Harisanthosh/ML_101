# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
import sys, re
from collections import Counter

# %%
try:
    text_word = input("Enter the text")
except:
    print("Excpetion thrown !")
# Out:
# Enter the textFeature Extraction: Use the representations learned by a previous network to extract meaningful features from new samples. You simply add a new classifier, which will be trained from scratch, on top of the pretrained model so that you can repurpose the feature maps learned previously for our dataset. You do not need to (re)train the entire model. The base convolutional network already contains features that are generically useful for classifying pictures. However, the final, classification part of the pretrained model is specific to original classification task, and subsequently specific to the set of classes on which the model was trained.

# %%
counter = Counter(word.lower()
                 for word in text_word.strip().split()
                 if word)

# %%
for word, count in counter.most_common():
    sys.stdout.write(word)
    sys.stdout.write("\t")
    sys.stdout.write(str(count))
    sys.stdout.write("\n")
# Out:
# the	9
# to	4
# you	3
# of	3
# model	3
# feature	2
# learned	2
# a	2
# network	2
# features	2
# from	2
# new	2
# which	2
# on	2
# pretrained	2
# that	2
# for	2
# classification	2
# specific	2
# extraction:	1
# use	1
# representations	1
# by	1
# previous	1
# extract	1
# meaningful	1
# samples.	1
# simply	1
# add	1
# classifier,	1
# will	1
# be	1
# trained	1
# scratch,	1
# top	1
# so	1
# can	1
# repurpose	1
# maps	1
# previously	1
# our	1
# dataset.	1
# do	1
# not	1
# need	1
# (re)train	1
# entire	1
# model.	1
# base	1
# convolutional	1
# already	1
# contains	1
# are	1
# generically	1
# useful	1
# classifying	1
# pictures.	1
# however,	1
# final,	1
# part	1
# is	1
# original	1
# task,	1
# and	1
# subsequently	1
# set	1
# classes	1
# was	1
# trained.	1

# %%
from bs4 import BeautifulSoup
import requests
html = requests.get("http://www.example.com").text
soup = BeautifulSoup(html, 'html5lib')

# %%
first_paragraph = soup.find('p')

# %%
first_paragraph_text = soup.p.text
first_paragraph_words = soup.p.text.split()

# %%
print(first_paragraph_text)
# Out:
# This domain is for use in illustrative examples in documents. You may use this
#     domain in literature without prior coordination or asking for permission.

# %%
def book_info(td):
    """given a BeautifulSoup <td> Tag representing a book,
     extract the book's details and return a dict"""
    title = td.find("div", "thumbheader").a.text
    by_author = td.find('div', 'AuthorName').text
    authors = [x.strip() for x in re.sub("^By ", "", by_author).split(",")]
    isbn_link = td.find("div", "thumbheader").a.get("href")
    isbn = re.match("/product/(.*)\.do", isbn_link).groups()[0]
    date = td.find("span", "directorydate").text.strip()
    return {
        "title" : title,
        "authors" : authors,
        "isbn" : isbn,
        "date" : date
    }

# %%
url = ("https://raw.githubusercontent.com/"
       "joelgrus/data/master/getting-data.html")
html = requests.get(url).text

# %%
soup = BeautifulSoup(html, 'html5lib')

first_paragraph = soup.find('p')

# %%
assert str(soup.find('p')) == '<p id="p1">This is the first paragraph.</p>'

# %%
import json

# %%
github_user = "Harisanthosh"
endpoint = f"https://api.github.com/users/{github_user}/repos"
    
repos = json.loads(requests.get(endpoint).text)

# %%
print(repos)
# Out:
# [{'id': 215708241, 'node_id': 'MDEwOlJlcG9zaXRvcnkyMTU3MDgyNDE=', 'name': 'API-Interface-for-ERP', 'full_name': 'Harisanthosh/API-Interface-for-ERP', 'private': False, 'owner': {'login': 'Harisanthosh', 'id': 21079172, 'node_id': 'MDQ6VXNlcjIxMDc5MTcy', 'avatar_url': 'https://avatars1.githubusercontent.com/u/21079172?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Harisanthosh', 'html_url': 'https://github.com/Harisanthosh', 'followers_url': 'https://api.github.com/users/Harisanthosh/followers', 'following_url': 'https://api.github.com/users/Harisanthosh/following{/other_user}', 'gists_url': 'https://api.github.com/users/Harisanthosh/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Harisanthosh/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Harisanthosh/subscriptions', 'organizations_url': 'https://api.github.com/users/Harisanthosh/orgs', 'repos_url': 'https://api.github.com/users/Harisanthosh/repos', 'events_url': 'https://api.github.com/users/Harisanthosh/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Harisanthosh/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/Harisanthosh/API-Interface-for-ERP', 'description': 'An API Explorer for PPS (Production Planning and Control) ERP System in Python', 'fork': False, 'url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP', 'forks_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/forks', 'keys_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/teams', 'hooks_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/hooks', 'issue_events_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/issues/events{/number}', 'events_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/events', 'assignees_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/assignees{/user}', 'branches_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/branches{/branch}', 'tags_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/tags', 'blobs_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/languages', 'stargazers_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/stargazers', 'contributors_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/contributors', 'subscribers_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/subscribers', 'subscription_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/subscription', 'commits_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/contents/{+path}', 'compare_url': 'https://api.github.com/repos/Harisanthosh/API-Interface-for-ERP/compare/{base}...{head}', 'merges_url': 'https://api.gi ...

# %%
last_5_repositories = sorted(repos,
                                 key=lambda r: r["pushed_at"],
                                 reverse=True)[:5]

for x in range(len(last_5_repositories)):
    print(last_5_repositories[x]['name'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-5c9c94cb2169> in <module>
#       3                                  reverse=True)[:5]
#       4
# ----> 5 for x in range(last_5_repositories):
#       6     print(last_5_repositories[x]['name'])
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
from dateutil.parser import parse

# %%
dates = [parse(repo["created_at"]) for repo in repos]
month_counts = Counter(date.month for date in dates)
weekday_counts = Counter(date.weekday() for date in dates)

print(dates)
print(month_counts)
print(weekday_counts)
# Out:
# [datetime.datetime(2019, 10, 17, 5, 13, 36, tzinfo=tzlocal()), datetime.datetime(2019, 6, 3, 12, 22, 41, tzinfo=tzlocal()), datetime.datetime(2018, 5, 14, 2, 38, 3, tzinfo=tzlocal()), datetime.datetime(2019, 5, 14, 16, 30, 44, tzinfo=tzlocal()), datetime.datetime(2019, 4, 17, 9, 40, 14, tzinfo=tzlocal()), datetime.datetime(2019, 5, 3, 13, 26, 7, tzinfo=tzlocal()), datetime.datetime(2016, 8, 17, 18, 20, 57, tzinfo=tzlocal()), datetime.datetime(2019, 9, 30, 7, 46, 55, tzinfo=tzlocal()), datetime.datetime(2018, 9, 13, 6, 3, 54, tzinfo=tzlocal()), datetime.datetime(2019, 10, 13, 14, 38, 58, tzinfo=tzlocal()), datetime.datetime(2016, 8, 17, 19, 6, tzinfo=tzlocal()), datetime.datetime(2019, 10, 2, 13, 10, tzinfo=tzlocal()), datetime.datetime(2019, 9, 21, 14, 22, 58, tzinfo=tzlocal()), datetime.datetime(2016, 8, 24, 2, 39, 27, tzinfo=tzlocal()), datetime.datetime(2018, 9, 3, 7, 54, 28, tzinfo=tzlocal()), datetime.datetime(2019, 10, 8, 17, 39, 5, tzinfo=tzlocal()), datetime.datetime(2016, 8, 18, 17, 11, 11, tzinfo=tzlocal()), datetime.datetime(2016, 8, 18, 2, 57, 49, tzinfo=tzlocal()), datetime.datetime(2019, 10, 19, 8, 4, 55, tzinfo=tzlocal()), datetime.datetime(2019, 9, 30, 3, 57, 8, tzinfo=tzlocal()), datetime.datetime(2017, 4, 15, 12, 39, 44, tzinfo=tzlocal()), datetime.datetime(2019, 10, 2, 13, 30, 3, tzinfo=tzlocal()), datetime.datetime(2019, 10, 7, 3, 47, 41, tzinfo=tzlocal()), datetime.datetime(2018, 9, 4, 5, 32, 54, tzinfo=tzlocal()), datetime.datetime(2018, 9, 20, 18, 21, 13, tzinfo=tzlocal()), datetime.datetime(2019, 10, 15, 3, 47, 49, tzinfo=tzlocal()), datetime.datetime(2019, 10, 4, 8, 29, 8, tzinfo=tzlocal()), datetime.datetime(2019, 10, 23, 6, 40, 51, tzinfo=tzlocal()), datetime.datetime(2019, 10, 28, 12, 12, 11, tzinfo=tzlocal()), datetime.datetime(2019, 9, 2, 12, 43, 11, tzinfo=tzlocal())]
# Counter({10: 11, 9: 8, 8: 5, 5: 3, 4: 2, 6: 1})
# Counter({0: 8, 2: 7, 3: 5, 1: 4, 5: 3, 4: 2, 6: 1})
